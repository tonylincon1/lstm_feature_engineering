# %% [markdown]
# # Predicting Earthquake damage to buildings

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd

from tqdm.notebook import tqdm

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, LSTM, Embedding

from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from imblearn.over_sampling import SMOTE

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Loading

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# path has been removed to maintain privacy
X = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Richter's Predictor: Modeling Earthquake Damage/data/train_values.csv", index_col='building_id')

# %%
X.head()
# Out:
#              geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# building_id
# 802906                    6             487           12198
# 28830                     8             900            2812
# 94947                    21             363            8973
# 590882                   22             418           10694
# 201944                   11             131            1488
#
#              count_floors_pre_eq  age  area_percentage  height_percentage  \
# building_id
# 802906                         2   30                6                  5
# 28830                          2   10                8                  7
# 94947                          2   10                5                  5
# 590882                         2   10                6                  5
# 201944                         3   30                8                  9
#
#             land_surface_condition foundation_type roof_type  ...  \
# building_id                                                   ...
# 802906                           t               r         n  ...
# 28830                            o               r         n  ...
# 94947                            t               r         n  ...
# 590882                           t               r         n  ...
# 201944                           t               r         n  ...
#
#             has_secondary_use_agriculture has_secondary_use_hotel  \
# building_id
# 802906                                  0                       0
# 28830                                   0                       0
# 94947                                   0                       0
# 590882                                  0                       0
# 201944                                  0                       0
#
#             has_secondary_use_rental has_secondary_use_institution  \
# building_id
# 802906                             0                             0
# 28830                              0                             0
# 94947                              0                             0
# 590882                             0                             0
# 201944                             0                             0
#
#              has_secondary_use_school  has_secondary_use_industry  \
# building_id
# 802906                              0                           0
# 28830                               0                           0
# 94947                               0                           0
# 590882                              0                           0
# 201944                              0                           0
#
#              has_secondary_use_health_post  has_secondary_use_gov_office  \
# building_id
# 802906                                   0                             0
# 28830                                    0                             0
# 94947                                    0                             0
# 590882                                   0                             0
# 201944                                   0                             0
#
#              has_secondary_use_use_police  has_secondary_use_other
# building_id
# 802906                                  0                        0
# 28830                                   0                        0
# 94947                                   0                        0
# 590882                                  0                        0
# 201944                                  0                        0
#
# [5 rows x 38 columns]

# %%
# path has been removed to maintain privacy
Y= pd.read_csv("/content/drive/My Drive/Colab Notebooks/Richter's Predictor: Modeling Earthquake Damage/data/train_labels.csv", index_col='building_id')

# %%
Y.head()
# Out:
#              damage_grade
# building_id
# 802906                  3
# 28830                   2
# 94947                   3
# 590882                  2
# 201944                  3

# %%
# path has been removed to maintain privacy
test = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Richter's Predictor: Modeling Earthquake Damage/data/test_values.csv", index_col='building_id')

# %%
X.describe()
# Out:
#        geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  \
# count   260601.000000   260601.000000   260601.000000        260601.000000
# mean        13.900353      701.074685     6257.876148             2.129723
# std          8.033617      412.710734     3646.369645             0.727665
# min          0.000000        0.000000        0.000000             1.000000
# 25%          7.000000      350.000000     3073.000000             2.000000
# 50%         12.000000      702.000000     6270.000000             2.000000
# 75%         21.000000     1050.000000     9412.000000             2.000000
# max         30.000000     1427.000000    12567.000000             9.000000
#
#                  age  area_percentage  height_percentage  \
# count  260601.000000    260601.000000      260601.000000
# mean       26.535029         8.018051           5.434365
# std        73.565937         4.392231           1.918418
# min         0.000000         1.000000           2.000000
# 25%        10.000000         5.000000           4.000000
# 50%        15.000000         7.000000           5.000000
# 75%        30.000000         9.000000           6.000000
# max       995.000000       100.000000          32.000000
#
#        has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  \
# count                 260601.000000                        260601.000000
# mean                       0.088645                             0.761935
# std                        0.284231                             0.425900
# min                        0.000000                             0.000000
# 25%                        0.000000                             1.000000
# 50%                        0.000000                             1.000000
# 75%                        0.000000                             1.000000
# max                        1.000000                             1.000000
#
#        has_superstructure_stone_flag  ...  has_secondary_use_agriculture  \
# count                  260601.000000  ...                  260601.000000
# mean                        0.034332  ...                       0.064378
# std                         0.182081  ...                       0.245426
# min                         0.000000  ...                       0.000000
# 25%                         0.000000  ...                       0.000000
# 50%                         0.000000  ...                       0.000000
# 75%                         0.000000  ...                       0.000000
# max                         1.000000  ...                       1.000000
#
#        has_secondary_use_hotel  has_secondary_use_rental  \
# count            260601.000000             260601.000000
# mean                  0.033626                  0.008101
# std                   0.180265                  0.089638
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   0.000000                  0.000000
# 75%                   0.000000                  0.000000
# max                   1.000000                  1.000000
#
#        has_secondary_use_institution  has_secondary_use_school  \
# count                  260601.000000             260601.000000
# mean                        0.000940                  0.000361
# std                         0.030647                  0.018989
# min                         0.000000                  0.000000
# 25%                         0.000000                  0.000000
# 50%                         0.000000                  0.000000
# 75%                         0.000000                  0.000000
# max                         1.000000                  1.000000
#
#        has_secondary_use_industry  has_secondary_use_health_post  \
# count               260601.000000                  260601.000000
# mean                     0.001071                       0.000188
# std                      0.032703                       0.013711
# min                      0.000000                       0.000000
# 25%                      0.000000                       0.000000
# 50%                      0.000000                       0.000000
# 75%                      0.000000                       0.000000
# max                      1.000000                       1.000000
#
#        has_secondary_use_gov_office  has_secondary_use_use_police  \
# count                 260601.000000                 260601.000000
# mean                       0.000146                      0.000088
# std                        0.012075                      0.009394
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.000000                      0.000000
# 75%                        0.000000                      0.000000
# max                        1.000000                      1.000000
#
#        has_secondary_use_other
# count            260601.000000
# mean                  0.005119
# std                   0.071364
# min                   0.000000
# 25%                   0.000000
# 50%                   0.000000
# 75%                   0.000000
# max                   1.000000
#
# [8 rows x 30 columns]

# %% [markdown]
# # EDA

# %%
sns.countplot(Y['damage_grade'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Feature Engineering : Conditional Probabilities of geo_levels

# %% [markdown]
# #### ID-1

# %%
fea = pd.merge(X, Y, on='building_id')

# %%
#this block of code calculates the probabilities
damage1 = {}
damage2 = {}
damage3 = {}

for i,j in (X['geo_level_1_id'].value_counts()).iteritems():
    
    n1 = len(fea[fea['damage_grade']==1][fea['geo_level_1_id']==i])
    n2 = len(fea[fea['damage_grade']==2][fea['geo_level_1_id']==i])
    n3 = len(fea[fea['damage_grade']==3][fea['geo_level_1_id']==i])

    damage1[i] = n1/j
    damage2[i] = n2/j
    damage3[i] = n3/j
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # Remove the CWD from sys.path while we load stuff.

# %%
# this block of code appends a new column/feature of probabilities
list1 = []
list2 = []
list3 = []

for i in X['geo_level_1_id']:
    list1.append(damage1.get(i))
    list2.append(damage2.get(i))
    list3.append(damage3.get(i))

X['prob1_geo1'] = list1
X['prob2_geo1'] = list2
X['prob3_geo1'] = list3

# %%
list1 = []
list2 = []
list3 = []

for i in test['geo_level_1_id']:
    list1.append(damage1.get(i))
    list2.append(damage2.get(i))
    list3.append(damage3.get(i))

test['prob1_geo1'] = list1
test['prob2_geo1'] = list2
test['prob3_geo1'] = list3

# %% [markdown]
# #### ID-2

# %%
damage1 = {}
damage2 = {}
damage3 = {}

for i,j in ((X['geo_level_2_id'].value_counts()).iteritems()):
    
    n1 = len(fea[fea['damage_grade']==1][fea['geo_level_2_id']==i])
    n2 = len(fea[fea['damage_grade']==2][fea['geo_level_2_id']==i])
    n3 = len(fea[fea['damage_grade']==3][fea['geo_level_2_id']==i])

    damage1[i] = n1/j
    damage2[i] = n2/j
    damage3[i] = n3/j
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':

# %%
list1 = []
list2 = []
list3 = []

for i in X['geo_level_2_id']:
    list1.append(damage1.get(i))
    list2.append(damage2.get(i))
    list3.append(damage3.get(i))

X['prob1_geo2'] = list1
X['prob2_geo2'] = list2
X['prob3_geo2'] = list3

# %%
list1 = []
list2 = []
list3 = []

for i in test['geo_level_2_id']:
    list1.append(damage1.get(i))
    list2.append(damage2.get(i))
    list3.append(damage3.get(i))

test['prob1_geo2'] = list1
test['prob2_geo2'] = list2
test['prob3_geo2'] = list3

# %% [markdown]
# #### ID-3

# %%
damage1 = {}
damage2 = {}
damage3 = {}

for i,j in ((X['geo_level_3_id'].value_counts()).iteritems()):
    
    n1 = len(fea[fea['damage_grade']==1][fea['geo_level_3_id']==i])
    n2 = len(fea[fea['damage_grade']==2][fea['geo_level_3_id']==i])
    n3 = len(fea[fea['damage_grade']==3][fea['geo_level_3_id']==i])

    damage1[i] = n1/j
    damage2[i] = n2/j
    damage3[i] = n3/j
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':

# %%
list1 = []
list2 = []
list3 = []

for i in X['geo_level_3_id']:
    list1.append(damage1.get(i))
    list2.append(damage2.get(i))
    list3.append(damage3.get(i))

X['prob1_geo3'] = list1
X['prob2_geo3'] = list2
X['prob3_geo3'] = list3

# %%
list1 = []
list2 = []
list3 = []

for i in test['geo_level_3_id']:
    list1.append(damage1.get(i))
    list2.append(damage2.get(i))
    list3.append(damage3.get(i))

test['prob1_geo3'] = list1
test['prob2_geo3'] = list2
test['prob3_geo3'] = list3

# %% [markdown]
# # Feature Engineering: Finding relation between geo_levels using seq_to_seq method (LSTM)

# %% [markdown]
# <font size=2> **Below is just an example to show how the geo_levels might be related in some way to each other.**
# **For geo_level_1 = 6 and geo_level_2=487 we see there are a lot of same geo_levels-3 indicating that there is some relation between these levels.**</font>

# %%
pd.DataFrame(X['geo_level_3_id'][X['geo_level_2_id']==487][X['geo_level_1_id']==6]).head(50)
# Out:
#              geo_level_3_id
# building_id
# 802906                12198
# 959468                12198
# 410679                 7439
# 423950                 7439
# 215003                12198
# 594969                  835
# 695349                 2908
# 869506                 7439
# 141511                  382
# 302373                12198
# 278030                 7439
# 468643                  139
# 301912                 7439
# 361127                  835
# 434762                 6936
# 820534                12198
# 403828                 1755
# 1003118                 139
# 11938                   382
# 323241                 7439
# 644442                  139
# 569291                12198
# 260227                  139
# 283562                  382
# 483948                12198
# 900047                  139
# 241763                 1755
# 138804                  139
# 412505                 1755
# 226288                  139
# 581654                  835
# 505958                 2908
# 332220                 6845
# 477823                12198
# 15925                  1755
# 876711                  382
# 298595                 1755
# 473330                  139
# 496583                  139
# 925649                  139
# 163967                12198
# 122224                12198
# 1052883                6845
# 313465                 6936
# 408889                 6845
# 835066                 7439
# 471550                 1755
# 516173                12198
# 860736                 1755
# 232308                  139

# %% [markdown]
# ### Converting the geo_levels 1 and 2 into one hot encoder with shared vocabulary

# %%
l1 = pd.concat([X['geo_level_1_id'], test['geo_level_1_id']])
l2 = pd.concat([X['geo_level_2_id'], test['geo_level_2_id']])
l3 = pd.concat([X['geo_level_3_id'], test['geo_level_3_id']])

# %%
#get shared vocab of l1 and l2
inp = pd.concat([l1,l2]).to_numpy().reshape(-1,1)

# %%
l1 = pd.concat([X['geo_level_1_id'], test['geo_level_1_id']]).to_numpy().reshape(-1,1)

# %%
l2 = pd.concat([X['geo_level_2_id'], test['geo_level_2_id']]).to_numpy().reshape(-1,1)

# %%
onehot = OneHotEncoder(sparse=False)

# %%
onehot.fit(inp)
# Out:
# OneHotEncoder(sparse=False)

# %%
inp.shape
# Out:
# (694938, 1)

# %%
onehot.categories_
# Out:
# [array([   0,    1,    2, ..., 1425, 1426, 1427])]

# %%
l1_hot = onehot.transform(l1)

# %%
l1_hot.shape
# Out:
# (347469, 1419)

# %%
l2_hot = onehot.transform(l2)

# %%
l2_hot.shape
# Out:
# (347469, 1419)

# %%
fin_inp = np.stack((l1_hot,l2_hot), axis=1)
fin_inp.shape
# Out:
# (347469, 2, 1419)

# %% [markdown]
# ### Converting geo_level_3 into onehot

# %%
l3_hot = np.array(pd.get_dummies(l3))

# %%
l3_hot.shape
# Out:
# (347469, 11861)

# %% [markdown]
# ### Creating a LSTM model to get relation features.

# %%
inpx = Input( shape=fin_inp.shape[1:] )  

lstm = LSTM(20, )(inpx)

lvl3 = Dense(l3_hot.shape[1], activation='sigmoid')(lstm)

modelf = Model(inputs= inpx, outputs=lvl3)

modelf.compile(loss='binary_crossentropy', optimizer='adam')

modelf.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2, 1419)]         0
#
#  lstm (LSTM)                 (None, 20)                115200
#
#  dense (Dense)               (None, 11861)             249081
#
# =================================================================
# Total params: 364,281
# Trainable params: 364,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelf.fit(fin_inp, l3_hot, epochs=10, batch_size=64)
# Out:
# Epoch 1/10
# 5430/5430 [==============================] - 28s 4ms/step - loss: 0.0185
# Epoch 2/10
# 5430/5430 [==============================] - 20s 4ms/step - loss: 8.3744e-04
# Epoch 3/10
# 5430/5430 [==============================] - 21s 4ms/step - loss: 8.3153e-04
# Epoch 4/10
# 5430/5430 [==============================] - 21s 4ms/step - loss: 8.3100e-04
# Epoch 5/10
# 5430/5430 [==============================] - 21s 4ms/step - loss: 8.3022e-04
# Epoch 6/10
# 5430/5430 [==============================] - 21s 4ms/step - loss: 8.0492e-04
# Epoch 7/10
# 5430/5430 [==============================] - 21s 4ms/step - loss: 7.5762e-04
# Epoch 8/10
# 5430/5430 [==============================] - 20s 4ms/step - loss: 7.1806e-04
# Epoch 9/10
# 5430/5430 [==============================] - 21s 4ms/step - loss: 6.8945e-04
# Epoch 10/10
# 5430/5430 [==============================] - 21s 4ms/step - loss: 6.7358e-04

# %% [markdown]
# ### Getting the relation vector from the output of intermediate layer

# %%
inter = Model(inputs=modelf.input, outputs=modelf.layers[1].output)

# %% [markdown]
# <font size=3>**Train**</font>

# %%
l1 = X['geo_level_1_id'].to_numpy().reshape(-1,1)

l2 = X['geo_level_2_id'].to_numpy().reshape(-1,1)

# %%
l1_hot = onehot.transform(l1)
l2_hot = onehot.transform(l2)

# %%
fin_inp = np.stack((l1_hot,l2_hot), axis=1)
fin_inp.shape
# Out:
# (260601, 2, 1419)

# %%
geo_fea_train = inter.predict(fin_inp)

# %% [markdown]
# <font size=3>**Test**</font>

# %%
l1 = test['geo_level_1_id'].to_numpy().reshape(-1,1)

l2 = test['geo_level_2_id'].to_numpy().reshape(-1,1)

# %%
l1_hot = onehot.transform(l1)
l2_hot = onehot.transform(l2)

# %%
fin_inp = np.stack((l1_hot,l2_hot), axis=1)
fin_inp.shape
# Out:
# (86868, 2, 1419)

# %%
geo_fea_test = inter.predict(fin_inp)

# %% [markdown]
# # Final  Data

# %%
print("train {}, test {}  ".format(geo_fea_train.shape, geo_fea_test.shape))
# Out:
# train (260601, 20), test (86868, 20)

# %% [markdown]
# ### Preprocessing the data with pd.get_dummies and adding the relation features

# %%
fx_tr = np.hstack((np.array(pd.get_dummies(X.copy().drop(['geo_level_1_id', 'geo_level_2_id', 'geo_level_3_id'], axis=1))),
                   geo_fea_train))

# %%
fx_tr
# Out:
# array([[ 2.        , 30.        ,  6.        , ..., -0.96190882,
#         -0.96277165, -0.96279091],
#        [ 2.        , 10.        ,  8.        , ..., -0.96242303,
#         -0.96305031, -0.96302485],
#        [ 2.        , 10.        ,  5.        , ..., -0.96072483,
#         -0.96176893, -0.96236229],
#        ...,
#        [ 3.        , 55.        ,  6.        , ..., -0.96199542,
#         -0.96292806, -0.96283406],
#        [ 2.        , 10.        , 14.        , ..., -0.96216935,
#         -0.96318471, -0.96332216],
#        [ 3.        , 10.        ,  7.        , ..., -0.95581418,
#         -0.96177083, -0.96236521]])

# %%
fx_tr.shape
# Out:
# (260601, 94)

# %%
test.fillna(value=0, inplace=True)

# %%
fx_te = np.hstack((np.array(pd.get_dummies(test.copy().drop(['geo_level_1_id', 'geo_level_2_id', 'geo_level_3_id'], axis=1))), geo_fea_test))

fx_te.shape
# Out:
# (86868, 94)

# %%
fy_tr = Y.to_numpy().ravel()
fy_tr.shape
# Out:
# (260601,)

# %% [markdown]
# # Applying machine learning

# %%
rf = RandomForestClassifier(random_state=42,criterion='entropy', max_depth=8, max_features='auto', n_estimators=200)
rf.fit(fx_tr,fy_tr)

predrf=rf.predict(fx_tr)

#f1 score is the metric used in the competition
accuracy1=f1_score(fy_tr,predrf,average='micro')
print("Score on test set")
print("\n ========================================================")
print(accuracy1)
print('\n Benchmark model was: 0.984')
# Out:
# Score on test set
#
#  ========================================================
# 0.750987141261929
#
#  Benchmark model was: 0.984

# %%
import lightgbm as lgb

modellgb = lgb.LGBMClassifier(colsample_bytree=0.7, max_depth=25, min_split_gain=0.3,
               num_leaves=200, random_seed=42, reg_alpha=1.3, reg_lambda=1.1,
               subsample=0.9, subsample_freq=20)
modellgb.fit(fx_tr, fy_tr)
predslgb=modellgb.predict(fx_tr)

#f1 score is the metric used in the competition
accuracy1=f1_score(fy_tr,predslgb,average='micro')
print("Score on test set")
print("\n ========================================================")
print(accuracy1)
print('\n Benchmark model was: 0.7898')
# Out:
# Score on test set
#
#  ========================================================
# 0.7890529967267969
#
#  Benchmark model was: 0.7898

# %%
#input best params here from randm.best_params_

# !pip install xgboost

import xgboost as xgb

modelxgb_cl = xgb.XGBClassifier(random_state=42,objective='multi:softmax', gamma=0.001369048068388758, eta=0.11,
                  max_depth= 20,
                  min_child_weight=9,
                  num_class= 4,
                  subsample= .85,
                  colsample_bytree= .9, verbose=10)
modelxgb_cl.fit(fx_tr, fy_tr)

predsxgb_cl=modelxgb_cl.predict(fx_tr)

#f1 score is the metric used in the competition
accuracy1=f1_score(fy_tr,predsxgb_cl,average='micro')
print("Score on test set")
print("\n ========================================================")
print(accuracy1)
print('\n Benchmark model was: 0.8712')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (0.90)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.21.6)
# Score on test set
#
#  ========================================================
# 0.8712591279388797
#
#  Benchmark model was: 0.8712

# %%
#input best params here from randm.best_params_
modelextratrees = ExtraTreesClassifier(random_state=42)

param_grid = {  
    "n_estimators": [360,500],
    "max_depth": [4,5,6,7,8,25,30,32] 
}

modelextratrees = GridSearchCV(estimator=modelextratrees, param_grid=param_grid, cv=2, scoring='f1_micro', verbose=10)
modelextratrees.fit(fx_tr, fy_tr)

predsextra=modelextratrees.predict(fx_tr)

#f1 score is the metric used in the competition
accuracy1=f1_score(fy_tr,predsextra,average='micro')
print("Score on test set")
print("\n ========================================================")
print(accuracy1)
print('\n Benchmark model was: 0.5815')
# Out:
# Fitting 2 folds for each of 16 candidates, totalling 32 fits
# [CV 1/2; 1/16] START max_depth=4, n_estimators=360..............................
# [CV 1/2; 1/16] END max_depth=4, n_estimators=360;, score=0.715 total time=  28.5s
# [CV 2/2; 1/16] START max_depth=4, n_estimators=360..............................
# [CV 2/2; 1/16] END max_depth=4, n_estimators=360;, score=0.714 total time=  27.4s
# [CV 1/2; 2/16] START max_depth=4, n_estimators=500..............................
# [CV 1/2; 2/16] END max_depth=4, n_estimators=500;, score=0.716 total time=  38.1s
# [CV 2/2; 2/16] START max_depth=4, n_estimators=500..............................
# [CV 2/2; 2/16] END max_depth=4, n_estimators=500;, score=0.714 total time=  37.9s
# [CV 1/2; 3/16] START max_depth=5, n_estimators=360..............................
# [CV 1/2; 3/16] END max_depth=5, n_estimators=360;, score=0.723 total time=  31.3s
# [CV 2/2; 3/16] START max_depth=5, n_estimators=360..............................
# [CV 2/2; 3/16] END max_depth=5, n_estimators=360;, score=0.723 total time=  31.5s
# [CV 1/2; 4/16] START max_depth=5, n_estimators=500..............................
# [CV 1/2; 4/16] END max_depth=5, n_estimators=500;, score=0.723 total time=  43.4s
# [CV 2/2; 4/16] START max_depth=5, n_estimators=500..............................
# [CV 2/2; 4/16] END max_depth=5, n_estimators=500;, score=0.723 total time=  43.2s
# [CV 1/2; 5/16] START max_depth=6, n_estimators=360..............................
# [CV 1/2; 5/16] END max_depth=6, n_estimators=360;, score=0.730 total time=  34.6s
# [CV 2/2; 5/16] START max_depth=6, n_estimators=360..............................
# [CV 2/2; 5/16] END max_depth=6, n_estimators=360;, score=0.730 total time=  34.5s
# [CV 1/2; 6/16] START max_depth=6, n_estimators=500..............................
# [CV 1/2; 6/16] END max_depth=6, n_estimators=500;, score=0.729 total time=  48.1s
# [CV 2/2; 6/16] START max_depth=6, n_estimators=500..............................
# [CV 2/2; 6/16] END max_depth=6, n_estimators=500;, score=0.730 total time=  48.1s
# [CV 1/2; 7/16] START max_depth=7, n_estimators=360..............................
# [CV 1/2; 7/16] END max_depth=7, n_estimators=360;, score=0.736 total time=  37.8s
# [CV 2/2; 7/16] START max_depth=7, n_estimators=360..............................
# [CV 2/2; 7/16] END max_depth=7, n_estimators=360;, score=0.734 total time=  38.0s
# [CV 1/2; 8/16] START max_depth=7, n_estimators=500..............................
# [CV 1/2; 8/16] END max_depth=7, n_estimators=500;, score=0.736 total time=  52.6s
# [CV 2/2; 8/16] START max_depth=7, n_estimators=500..............................
# [CV 2/2; 8/16] END max_depth=7, n_estimators=500;, score=0.735 total time=  52.6s
# [CV 1/2; 9/16] START max_depth=8, n_estimators=360..............................
# [CV 1/2; 9/16] END max_depth=8, n_estimators=360;, score=0.739 total time=  41.0s
# [CV 2/2; 9/16] START max_depth=8, n_estimators=360..............................
# [CV 2/2; 9/16] END max_depth=8, n_estimators=360;, score=0.739 total time=  41.3s
# [CV 1/2; 10/16] START max_depth=8, n_estimators=500.............................
# [CV 1/2; 10/16] END max_depth=8, n_estimators=500;, score=0.739 total time=  56.8s
# [CV 2/2; 10/16] START max_depth=8, n_estimators=500.............................
# [CV 2/2; 10/16] END max_depth=8, n_estimators=500;, score=0.740 total time=  56.8s
# [CV 1/2; 11/16] START max_depth=25, n_estimators=360............................
# [CV 1/2; 11/16] END max_depth=25, n_estimators=360;, score=0.744 total time= 1.5min
# [CV 2/2; 11/16] START max_depth=25, n_estimators=360............................
# [CV 2/2; 11/16] END max_depth=25, n_estimators=360;, score=0.744 total time= 1.5min
# [CV 1/2; 12/16] START max_depth=25, n_estimators=500............................
# [CV 1/2; 12/16] END max_depth=25, n_estimators=500;, score=0.744 total time= 2.1min
# [CV 2/2; 12/16] START max_depth=25, n_estimators=500............................
# [CV 2/2; 12/16] END max_depth=25, n_estimators=500;, score=0.744 total time= 2.1min
# [CV 1/2; 13/16] START max_depth=30, n_estimators=360............................
# [CV 1/2; 13/16] END max_depth=30, n_estimators=360;, score=0.731 total time= 1.7min
# [CV 2/2; 13/16] START max_depth=30, n_estimators=360............................
# [CV 2/2; 13/16] END max_depth=30, n_estimators=360;, score=0.732 total time= 1.7min
# [CV 1/2; 14/16] START max_depth=30, n_estimators=500............................
# [CV 1/2; 14/16] END max_depth=30, n_estimators=500;, score=0.731 total time= 2.3min
# [CV 2/2; 14/16] START max_depth=30, n_estimators=500............................
# [CV 2/2; 14/16] END max_depth=30, n_estimators=500;, score=0.732 total time= 2.4min
# [CV 1/2; 15/16] START max_depth=32, n_estimators=360............................
# [CV 1/2; 15/16] END max_depth=32, n_estimators=360;, score=0.727 total time= 1.7min
# [CV 2/2; 15/16] START max_depth=32, n_estimators=360............................
# [CV 2/2; 15/16] END max_depth=32, n_estimators=360;, score=0.728 total time= 1.7min
# [CV 1/2; 16/16] START max_depth=32, n_estimators=500............................
# [CV 1/2; 16/16] END max_depth=32, n_estimators=500;, score=0.727 total time= 2.4min
# [CV 2/2; 16/16] START max_depth=32, n_estimators=500............................
# [CV 2/2; 16/16] END max_depth=32, n_estimators=500;, score=0.728 total time= 2.4min
# Score on test set
#
#  ========================================================
# 0.898212209469649
#
#  Benchmark model was: 0.5815

# %%
modelextratrees.best_params_
# Out:
# {'max_depth': 25, 'n_estimators': 500}

# %%
from sklearn.ensemble import GradientBoostingClassifier

modelgradient = GradientBoostingClassifier(random_state=42, learning_rate=0.15,loss='deviance', max_depth=8, max_features='sqrt',n_estimators= 400,subsample=0.85)
modelgradient.fit(fx_tr, fy_tr)

predsgradient=modelgradient.predict(fx_tr)

#f1 score is the metric used in the competition
accuracy1=f1_score(fy_tr,predsgradient,average='micro')
print("Score on test set")
print("\n ========================================================")
print(accuracy1)
print('\n Benchmark model was: 0.8712')
# Out:
# Score on test set
#
#  ========================================================
# 0.8342715492265954
#
#  Benchmark model was: 0.8712

# %%
# %%time

from sklearn.ensemble import VotingClassifier

voting_clf_1 = VotingClassifier(estimators=[('rf', rf),
                                          ('lgb',modellgb),
                                          ('gradient',modelgradient),
                                          ('extra',modelextratrees),
                                          ('xbg', modelxgb_cl)], voting='soft', verbose=10)
voting_clf_1.fit(fx_tr, fy_tr)
# Out:
# [Voting] ....................... (1 of 5) Processing rf, total=  57.4s
# [Voting] ...................... (2 of 5) Processing lgb, total=  35.0s
# [Voting] ................. (3 of 5) Processing gradient, total=11.6min
# Fitting 2 folds for each of 16 candidates, totalling 32 fits
# [CV 1/2; 1/16] START max_depth=4, n_estimators=360..............................
# [CV 1/2; 1/16] END max_depth=4, n_estimators=360;, score=0.715 total time=  34.4s
# [CV 2/2; 1/16] START max_depth=4, n_estimators=360..............................
# [CV 2/2; 1/16] END max_depth=4, n_estimators=360;, score=0.714 total time=  34.6s
# [CV 1/2; 2/16] START max_depth=4, n_estimators=500..............................
# [CV 1/2; 2/16] END max_depth=4, n_estimators=500;, score=0.716 total time=  48.0s
# [CV 2/2; 2/16] START max_depth=4, n_estimators=500..............................
# [CV 2/2; 2/16] END max_depth=4, n_estimators=500;, score=0.714 total time=  48.2s
# [CV 1/2; 3/16] START max_depth=5, n_estimators=360..............................
# [CV 1/2; 3/16] END max_depth=5, n_estimators=360;, score=0.723 total time=  39.7s
# [CV 2/2; 3/16] START max_depth=5, n_estimators=360..............................
# [CV 2/2; 3/16] END max_depth=5, n_estimators=360;, score=0.723 total time=  39.8s
# [CV 1/2; 4/16] START max_depth=5, n_estimators=500..............................
# [CV 1/2; 4/16] END max_depth=5, n_estimators=500;, score=0.723 total time=  54.9s
# [CV 2/2; 4/16] START max_depth=5, n_estimators=500..............................
# [CV 2/2; 4/16] END max_depth=5, n_estimators=500;, score=0.723 total time=  53.8s
# [CV 1/2; 5/16] START max_depth=6, n_estimators=360..............................
# [CV 1/2; 5/16] END max_depth=6, n_estimators=360;, score=0.730 total time=  47.3s
# [CV 2/2; 5/16] START max_depth=6, n_estimators=360..............................
# [CV 2/2; 5/16] END max_depth=6, n_estimators=360;, score=0.730 total time=  47.2s
# [CV 1/2; 6/16] START max_depth=6, n_estimators=500..............................
# [CV 1/2; 6/16] END max_depth=6, n_estimators=500;, score=0.729 total time= 1.1min
# [CV 2/2; 6/16] START max_depth=6, n_estimators=500..............................
# [CV 2/2; 6/16] END max_depth=6, n_estimators=500;, score=0.730 total time= 1.1min
# [CV 1/2; 7/16] START max_depth=7, n_estimators=360..............................
# [CV 1/2; 7/16] END max_depth=7, n_estimators=360;, score=0.736 total time=  51.3s
# [CV 2/2; 7/16] START max_depth=7, n_estimators=360..............................
# [CV 2/2; 7/16] END max_depth=7, n_estimators=360;, score=0.734 total time=  51.2s
# [CV 1/2; 8/16] START max_depth=7, n_estimators=500..............................
# [CV 1/2; 8/16] END max_depth=7, n_estimators=500;, score=0.736 total time= 1.2min
# [CV 2/2; 8/16] START max_depth=7, n_estimators=500..............................
# [CV 2/2; 8/16] END max_depth=7, n_estimators=500;, score=0.735 total time= 1.1min
# [CV 1/2; 9/16] START max_depth=8, n_estimators=360..............................
# [CV 1/2; 9/16] END max_depth=8, n_estimators=360;, score=0.739 total time=  47.6s
# [CV 2/2; 9/16] START max_depth=8, n_estimators=360..............................
# [CV 2/2; 9/16] END max_depth=8, n_estimators=360;, score=0.739 total time=  52.5s
# [CV 1/2; 10/16] START max_depth=8, n_estimators=500.............................
# [CV 1/2; 10/16] END max_depth=8, n_estimators=500;, score=0.739 total time= 1.2min
# [CV 2/2; 10/16] START max_depth=8, n_estimators=500.............................
# [CV 2/2; 10/16] END max_depth=8, n_estimators=500;, score=0.740 total time= 1.0min
# [CV 1/2; 11/16] START max_depth=25, n_estimators=360............................
# [CV 1/2; 11/16] END max_depth=25, n_estimators=360;, score=0.744 total time= 1.6min
# [CV 2/2; 11/16] START max_depth=25, n_estimators=360............................
# [CV 2/2; 11/16] END max_depth=25, n_estimators=360;, score=0.744 total time= 1.6min
# [CV 1/2; 12/16] START max_depth=25, n_estimators=500............................
# [CV 1/2; 12/16] END max_depth=25, n_estimators=500;, score=0.744 total time= 2.3min
# [CV 2/2; 12/16] START max_depth=25, n_estimators=500............................
# [CV 2/2; 12/16] END max_depth=25, n_estimators=500;, score=0.744 total time= 2.3min
# [CV 1/2; 13/16] START max_depth=30, n_estimators=360............................
# [CV 1/2; 13/16] END max_depth=30, n_estimators=360;, score=0.731 total time= 1.7min
# [CV 2/2; 13/16] START max_depth=30, n_estimators=360............................
# [CV 2/2; 13/16] END max_depth=30, n_estimators=360;, score=0.732 total time= 1.7min
# [CV 1/2; 14/16] START max_depth=30, n_estimators=500............................
# [CV 1/2; 14/16] END max_depth=30, n_estimators=500;, score=0.731 total time= 2.5min
# [CV 2/2; 14/16] START max_depth=30, n_estimators=500............................
# [CV 2/2; 14/16] END max_depth=30, n_estimators=500;, score=0.732 total time= 2.5min
# [CV 1/2; 15/16] START max_depth=32, n_estimators=360............................
# [CV 1/2; 15/16] END max_depth=32, n_estimators=360;, score=0.727 total time= 1.8min
# [CV 2/2; 15/16] START max_depth=32, n_estimators=360............................
# [CV 2/2; 15/16] END max_depth=32, n_estimators=360;, score=0.728 total time= 1.8min
# [CV 1/2; 16/16] START max_depth=32, n_estimators=500............................
# [CV 1/2; 16/16] END max_depth=32, n_estimators=500;, score=0.727 total time= 2.6min
# [CV 2/2; 16/16] START max_depth=32, n_estimators=500............................
# [CV 2/2; 16/16] END max_depth=32, n_estimators=500;, score=0.728 total time= 2.5min
# [Voting] .................... (4 of 5) Processing extra, total=48.5min
# [Voting] ...................... (5 of 5) Processing xbg, total=23.5min
# CPU times: user 1h 23min 17s, sys: 2min 12s, total: 1h 25min 30s
# Wall time: 1h 25min 5s

# %%
# %%time

voting_clf_2 = VotingClassifier(estimators=[('rf', rf),
                                          ('gradient',modelgradient),
                                          ('xbg', modelxgb_cl)], voting='soft', verbose=10)
voting_clf_2.fit(fx_tr, fy_tr)
# Out:
# [Voting] ....................... (1 of 3) Processing rf, total=  53.4s
# [Voting] ................. (2 of 3) Processing gradient, total= 9.5min
# [Voting] ...................... (3 of 3) Processing xbg, total=23.5min
# CPU times: user 33min 54s, sys: 2.66 s, total: 33min 57s
# Wall time: 33min 50s

# %%
# %%time

voting_clf_3 = VotingClassifier(estimators=[('lgb',modellgb),
                                          ('gradient',modelgradient),
                                          ('xbg', modelxgb_cl)], voting='soft', verbose=10)
voting_clf_3.fit(fx_tr, fy_tr)
# Out:
# [Voting] ...................... (1 of 3) Processing lgb, total=  35.3s
# [Voting] ................. (2 of 3) Processing gradient, total= 9.7min
# [Voting] ...................... (3 of 3) Processing xbg, total=23.6min
# CPU times: user 33min 51s, sys: 2.82 s, total: 33min 54s
# Wall time: 33min 49s

# %%
# %%time

voting_clf_4 = VotingClassifier(estimators=[('rf', rf),
                                          ('extra',modelextratrees),
                                          ('lgb',modellgb)], voting='soft', verbose=10)
voting_clf_4.fit(fx_tr, fy_tr)
# Out:
# [Voting] ....................... (1 of 3) Processing rf, total=  54.4s
# Fitting 2 folds for each of 16 candidates, totalling 32 fits
# [CV 1/2; 1/16] START max_depth=4, n_estimators=360..............................
# [CV 1/2; 1/16] END max_depth=4, n_estimators=360;, score=0.715 total time=  31.6s
# [CV 2/2; 1/16] START max_depth=4, n_estimators=360..............................
# [CV 2/2; 1/16] END max_depth=4, n_estimators=360;, score=0.714 total time=  31.6s
# [CV 1/2; 2/16] START max_depth=4, n_estimators=500..............................
# [CV 1/2; 2/16] END max_depth=4, n_estimators=500;, score=0.716 total time=  43.8s
# [CV 2/2; 2/16] START max_depth=4, n_estimators=500..............................
# [CV 2/2; 2/16] END max_depth=4, n_estimators=500;, score=0.714 total time=  43.9s
# [CV 1/2; 3/16] START max_depth=5, n_estimators=360..............................
# [CV 1/2; 3/16] END max_depth=5, n_estimators=360;, score=0.723 total time=  37.4s
# [CV 2/2; 3/16] START max_depth=5, n_estimators=360..............................
# [CV 2/2; 3/16] END max_depth=5, n_estimators=360;, score=0.723 total time=  37.4s
# [CV 1/2; 4/16] START max_depth=5, n_estimators=500..............................
# [CV 1/2; 4/16] END max_depth=5, n_estimators=500;, score=0.723 total time=  52.0s
# [CV 2/2; 4/16] START max_depth=5, n_estimators=500..............................
# [CV 2/2; 4/16] END max_depth=5, n_estimators=500;, score=0.723 total time=  52.2s
# [CV 1/2; 5/16] START max_depth=6, n_estimators=360..............................
# [CV 1/2; 5/16] END max_depth=6, n_estimators=360;, score=0.730 total time=  43.1s
# [CV 2/2; 5/16] START max_depth=6, n_estimators=360..............................
# [CV 2/2; 5/16] END max_depth=6, n_estimators=360;, score=0.730 total time=  42.6s
# [CV 1/2; 6/16] START max_depth=6, n_estimators=500..............................
# [CV 1/2; 6/16] END max_depth=6, n_estimators=500;, score=0.729 total time=  59.7s
# [CV 2/2; 6/16] START max_depth=6, n_estimators=500..............................
# [CV 2/2; 6/16] END max_depth=6, n_estimators=500;, score=0.730 total time=  59.8s
# [CV 1/2; 7/16] START max_depth=7, n_estimators=360..............................
# [CV 1/2; 7/16] END max_depth=7, n_estimators=360;, score=0.736 total time=  48.5s
# [CV 2/2; 7/16] START max_depth=7, n_estimators=360..............................
# [CV 2/2; 7/16] END max_depth=7, n_estimators=360;, score=0.734 total time=  48.5s
# [CV 1/2; 8/16] START max_depth=7, n_estimators=500..............................
# [CV 1/2; 8/16] END max_depth=7, n_estimators=500;, score=0.736 total time= 1.1min
# [CV 2/2; 8/16] START max_depth=7, n_estimators=500..............................
# [CV 2/2; 8/16] END max_depth=7, n_estimators=500;, score=0.735 total time= 1.1min
# [CV 1/2; 9/16] START max_depth=8, n_estimators=360..............................
# [CV 1/2; 9/16] END max_depth=8, n_estimators=360;, score=0.739 total time=  52.2s
# [CV 2/2; 9/16] START max_depth=8, n_estimators=360..............................
# [CV 2/2; 9/16] END max_depth=8, n_estimators=360;, score=0.739 total time=  52.1s
# [CV 1/2; 10/16] START max_depth=8, n_estimators=500.............................
# [CV 1/2; 10/16] END max_depth=8, n_estimators=500;, score=0.739 total time= 1.2min
# [CV 2/2; 10/16] START max_depth=8, n_estimators=500.............................
# [CV 2/2; 10/16] END max_depth=8, n_estimators=500;, score=0.740 total time= 1.2min
# [CV 1/2; 11/16] START max_depth=25, n_estimators=360............................
# [CV 1/2; 11/16] END max_depth=25, n_estimators=360;, score=0.744 total time= 1.9min
# [CV 2/2; 11/16] START max_depth=25, n_estimators=360............................
# [CV 2/2; 11/16] END max_depth=25, n_estimators=360;, score=0.744 total time= 2.0min
# [CV 1/2; 12/16] START max_depth=25, n_estimators=500............................
# [CV 1/2; 12/16] END max_depth=25, n_estimators=500;, score=0.744 total time= 2.9min
# [CV 2/2; 12/16] START max_depth=25, n_estimators=500............................
# [CV 2/2; 12/16] END max_depth=25, n_estimators=500;, score=0.744 total time= 2.9min
# [CV 1/2; 13/16] START max_depth=30, n_estimators=360............................
# [CV 1/2; 13/16] END max_depth=30, n_estimators=360;, score=0.731 total time= 2.2min
# [CV 2/2; 13/16] START max_depth=30, n_estimators=360............................
# [CV 2/2; 13/16] END max_depth=30, n_estimators=360;, score=0.732 total time= 2.2min
# [CV 1/2; 14/16] START max_depth=30, n_estimators=500............................
# [CV 1/2; 14/16] END max_depth=30, n_estimators=500;, score=0.731 total time= 3.0min
# [CV 2/2; 14/16] START max_depth=30, n_estimators=500............................
# [CV 2/2; 14/16] END max_depth=30, n_estimators=500;, score=0.732 total time= 3.0min
# [CV 1/2; 15/16] START max_depth=32, n_estimators=360............................
# [CV 1/2; 15/16] END max_depth=32, n_estimators=360;, score=0.727 total time= 2.2min
# [CV 2/2; 15/16] START max_depth=32, n_estimators=360............................
# [CV 2/2; 15/16] END max_depth=32, n_estimators=360;, score=0.728 total time= 2.3min
# [CV 1/2; 16/16] START max_depth=32, n_estimators=500............................
# [CV 1/2; 16/16] END max_depth=32, n_estimators=500;, score=0.727 total time= 3.1min
# [CV 2/2; 16/16] START max_depth=32, n_estimators=500............................
# [CV 2/2; 16/16] END max_depth=32, n_estimators=500;, score=0.728 total time= 3.1min
# [Voting] .................... (2 of 3) Processing extra, total=52.1min
# [Voting] ...................... (3 of 3) Processing lgb, total=  34.6s
# CPU times: user 51min 26s, sys: 2min 17s, total: 53min 43s
# Wall time: 53min 35s

# %%
# %%time

voting_clf_5 = VotingClassifier(estimators=[('rf', rf),
                                          ('extra',modelextratrees),
                                          ('xbg', modelxgb_cl)], voting='soft', verbose=10)
voting_clf_5.fit(fx_tr, fy_tr)
# Out:
# [Voting] ....................... (1 of 3) Processing rf, total= 1.5min
# Fitting 2 folds for each of 16 candidates, totalling 32 fits
# [CV 1/2; 1/16] START max_depth=4, n_estimators=360..............................
# [CV 1/2; 1/16] END max_depth=4, n_estimators=360;, score=0.715 total time=  36.0s
# [CV 2/2; 1/16] START max_depth=4, n_estimators=360..............................
# [CV 2/2; 1/16] END max_depth=4, n_estimators=360;, score=0.714 total time=  36.0s
# [CV 1/2; 2/16] START max_depth=4, n_estimators=500..............................
# [CV 1/2; 2/16] END max_depth=4, n_estimators=500;, score=0.716 total time=  49.9s
# [CV 2/2; 2/16] START max_depth=4, n_estimators=500..............................
# [CV 2/2; 2/16] END max_depth=4, n_estimators=500;, score=0.714 total time=  50.8s
# [CV 1/2; 3/16] START max_depth=5, n_estimators=360..............................
# [CV 1/2; 3/16] END max_depth=5, n_estimators=360;, score=0.723 total time=  43.7s
# [CV 2/2; 3/16] START max_depth=5, n_estimators=360..............................
# [CV 2/2; 3/16] END max_depth=5, n_estimators=360;, score=0.723 total time=  43.4s
# [CV 1/2; 4/16] START max_depth=5, n_estimators=500..............................
# [CV 1/2; 4/16] END max_depth=5, n_estimators=500;, score=0.723 total time=  58.1s
# [CV 2/2; 4/16] START max_depth=5, n_estimators=500..............................
# [CV 2/2; 4/16] END max_depth=5, n_estimators=500;, score=0.723 total time=  58.0s
# [CV 1/2; 5/16] START max_depth=6, n_estimators=360..............................
# [CV 1/2; 5/16] END max_depth=6, n_estimators=360;, score=0.730 total time=  47.3s
# [CV 2/2; 5/16] START max_depth=6, n_estimators=360..............................
# [CV 2/2; 5/16] END max_depth=6, n_estimators=360;, score=0.730 total time=  47.1s
# [CV 1/2; 6/16] START max_depth=6, n_estimators=500..............................
# [CV 1/2; 6/16] END max_depth=6, n_estimators=500;, score=0.729 total time= 1.1min
# [CV 2/2; 6/16] START max_depth=6, n_estimators=500..............................
# [CV 2/2; 6/16] END max_depth=6, n_estimators=500;, score=0.730 total time= 1.1min
# [CV 1/2; 7/16] START max_depth=7, n_estimators=360..............................
# [CV 1/2; 7/16] END max_depth=7, n_estimators=360;, score=0.736 total time=  52.4s
# [CV 2/2; 7/16] START max_depth=7, n_estimators=360..............................
# [CV 2/2; 7/16] END max_depth=7, n_estimators=360;, score=0.734 total time=  52.3s
# [CV 1/2; 8/16] START max_depth=7, n_estimators=500..............................
# [CV 1/2; 8/16] END max_depth=7, n_estimators=500;, score=0.736 total time= 1.2min
# [CV 2/2; 8/16] START max_depth=7, n_estimators=500..............................
# [CV 2/2; 8/16] END max_depth=7, n_estimators=500;, score=0.735 total time= 1.2min
# [CV 1/2; 9/16] START max_depth=8, n_estimators=360..............................
# [CV 1/2; 9/16] END max_depth=8, n_estimators=360;, score=0.739 total time=  57.5s
# [CV 2/2; 9/16] START max_depth=8, n_estimators=360..............................
# [CV 2/2; 9/16] END max_depth=8, n_estimators=360;, score=0.739 total time=  57.0s
# [CV 1/2; 10/16] START max_depth=8, n_estimators=500.............................
# [CV 1/2; 10/16] END max_depth=8, n_estimators=500;, score=0.739 total time= 1.3min
# [CV 2/2; 10/16] START max_depth=8, n_estimators=500.............................
# [CV 2/2; 10/16] END max_depth=8, n_estimators=500;, score=0.740 total time= 1.3min
# [CV 1/2; 11/16] START max_depth=25, n_estimators=360............................
# [CV 1/2; 11/16] END max_depth=25, n_estimators=360;, score=0.744 total time= 2.1min
# [CV 2/2; 11/16] START max_depth=25, n_estimators=360............................
# [CV 2/2; 11/16] END max_depth=25, n_estimators=360;, score=0.744 total time= 1.5min
# [CV 1/2; 12/16] START max_depth=25, n_estimators=500............................
# [CV 1/2; 12/16] END max_depth=25, n_estimators=500;, score=0.744 total time= 2.1min
# [CV 2/2; 12/16] START max_depth=25, n_estimators=500............................
# [CV 2/2; 12/16] END max_depth=25, n_estimators=500;, score=0.744 total time= 2.1min
# [CV 1/2; 13/16] START max_depth=30, n_estimators=360............................
# [CV 1/2; 13/16] END max_depth=30, n_estimators=360;, score=0.731 total time= 1.7min
# [CV 2/2; 13/16] START max_depth=30, n_estimators=360............................
# [CV 2/2; 13/16] END max_depth=30, n_estimators=360;, score=0.732 total time= 1.7min
# [CV 1/2; 14/16] START max_depth=30, n_estimators=500............................
# [CV 1/2; 14/16] END max_depth=30, n_estimators=500;, score=0.731 total time= 2.4min
# [CV 2/2; 14/16] START max_depth=30, n_estimators=500............................
# [CV 2/2; 14/16] END max_depth=30, n_estimators=500;, score=0.732 total time= 2.4min
# [CV 1/2; 15/16] START max_depth=32, n_estimators=360............................
# [CV 1/2; 15/16] END max_depth=32, n_estimators=360;, score=0.727 total time= 1.8min
# [CV 2/2; 15/16] START max_depth=32, n_estimators=360............................
# [CV 2/2; 15/16] END max_depth=32, n_estimators=360;, score=0.728 total time= 1.8min
# [CV 1/2; 16/16] START max_depth=32, n_estimators=500............................
# [CV 1/2; 16/16] END max_depth=32, n_estimators=500;, score=0.727 total time= 2.4min
# [CV 2/2; 16/16] START max_depth=32, n_estimators=500............................
# [CV 2/2; 16/16] END max_depth=32, n_estimators=500;, score=0.728 total time= 2.4min
# [Voting] .................... (2 of 3) Processing extra, total=49.2min
# [Voting] ...................... (3 of 3) Processing xbg, total=23.5min
# CPU times: user 1h 10min 4s, sys: 4min 12s, total: 1h 14min 17s
# Wall time: 1h 14min 6s

# %%
# %%time

voting_clf_6 = VotingClassifier(estimators=[('rf', rf),
                                          ('extra',modelextratrees),
                                          ('gradient',modelgradient)], voting='soft', verbose=10)
voting_clf_6.fit(fx_tr, fy_tr)
# Out:
# [Voting] ....................... (1 of 3) Processing rf, total= 1.1min
# Fitting 2 folds for each of 16 candidates, totalling 32 fits
# [CV 1/2; 1/16] START max_depth=4, n_estimators=360..............................
# [CV 1/2; 1/16] END max_depth=4, n_estimators=360;, score=0.715 total time=  30.5s
# [CV 2/2; 1/16] START max_depth=4, n_estimators=360..............................
# [CV 2/2; 1/16] END max_depth=4, n_estimators=360;, score=0.714 total time=  30.6s
# [CV 1/2; 2/16] START max_depth=4, n_estimators=500..............................
# [CV 1/2; 2/16] END max_depth=4, n_estimators=500;, score=0.716 total time=  42.5s
# [CV 2/2; 2/16] START max_depth=4, n_estimators=500..............................
# [CV 2/2; 2/16] END max_depth=4, n_estimators=500;, score=0.714 total time=  42.5s
# [CV 1/2; 3/16] START max_depth=5, n_estimators=360..............................
# [CV 1/2; 3/16] END max_depth=5, n_estimators=360;, score=0.723 total time=  36.1s
# [CV 2/2; 3/16] START max_depth=5, n_estimators=360..............................
# [CV 2/2; 3/16] END max_depth=5, n_estimators=360;, score=0.723 total time=  36.3s
# [CV 1/2; 4/16] START max_depth=5, n_estimators=500..............................
# [CV 1/2; 4/16] END max_depth=5, n_estimators=500;, score=0.723 total time=  50.1s
# [CV 2/2; 4/16] START max_depth=5, n_estimators=500..............................
# [CV 2/2; 4/16] END max_depth=5, n_estimators=500;, score=0.723 total time=  50.2s
# [CV 1/2; 5/16] START max_depth=6, n_estimators=360..............................
# [CV 1/2; 5/16] END max_depth=6, n_estimators=360;, score=0.730 total time=  41.8s
# [CV 2/2; 5/16] START max_depth=6, n_estimators=360..............................
# [CV 2/2; 5/16] END max_depth=6, n_estimators=360;, score=0.730 total time=  41.6s
# [CV 1/2; 6/16] START max_depth=6, n_estimators=500..............................
# [CV 1/2; 6/16] END max_depth=6, n_estimators=500;, score=0.729 total time=  57.9s
# [CV 2/2; 6/16] START max_depth=6, n_estimators=500..............................
# [CV 2/2; 6/16] END max_depth=6, n_estimators=500;, score=0.730 total time=  57.7s
# [CV 1/2; 7/16] START max_depth=7, n_estimators=360..............................
# [CV 1/2; 7/16] END max_depth=7, n_estimators=360;, score=0.736 total time=  46.9s
# [CV 2/2; 7/16] START max_depth=7, n_estimators=360..............................
# [CV 2/2; 7/16] END max_depth=7, n_estimators=360;, score=0.734 total time=  46.9s
# [CV 1/2; 8/16] START max_depth=7, n_estimators=500..............................
# [CV 1/2; 8/16] END max_depth=7, n_estimators=500;, score=0.736 total time= 1.1min
# [CV 2/2; 8/16] START max_depth=7, n_estimators=500..............................
# [CV 2/2; 8/16] END max_depth=7, n_estimators=500;, score=0.735 total time= 1.1min
# [CV 1/2; 9/16] START max_depth=8, n_estimators=360..............................
# [CV 1/2; 9/16] END max_depth=8, n_estimators=360;, score=0.739 total time=  52.0s
# [CV 2/2; 9/16] START max_depth=8, n_estimators=360..............................
# [CV 2/2; 9/16] END max_depth=8, n_estimators=360;, score=0.739 total time=  51.9s
# [CV 1/2; 10/16] START max_depth=8, n_estimators=500.............................
# [CV 1/2; 10/16] END max_depth=8, n_estimators=500;, score=0.739 total time= 1.2min
# [CV 2/2; 10/16] START max_depth=8, n_estimators=500.............................
# [CV 2/2; 10/16] END max_depth=8, n_estimators=500;, score=0.740 total time= 1.2min
# [CV 1/2; 11/16] START max_depth=25, n_estimators=360............................
# [CV 1/2; 11/16] END max_depth=25, n_estimators=360;, score=0.744 total time= 2.0min
# [CV 2/2; 11/16] START max_depth=25, n_estimators=360............................
# [CV 2/2; 11/16] END max_depth=25, n_estimators=360;, score=0.744 total time= 2.0min
# [CV 1/2; 12/16] START max_depth=25, n_estimators=500............................
# [CV 1/2; 12/16] END max_depth=25, n_estimators=500;, score=0.744 total time= 2.7min
# [CV 2/2; 12/16] START max_depth=25, n_estimators=500............................
# [CV 2/2; 12/16] END max_depth=25, n_estimators=500;, score=0.744 total time= 2.7min
# [CV 1/2; 13/16] START max_depth=30, n_estimators=360............................
# [CV 1/2; 13/16] END max_depth=30, n_estimators=360;, score=0.731 total time= 2.3min
# [CV 2/2; 13/16] START max_depth=30, n_estimators=360............................
# [CV 2/2; 13/16] END max_depth=30, n_estimators=360;, score=0.732 total time= 2.3min
# [CV 1/2; 14/16] START max_depth=30, n_estimators=500............................
# [CV 1/2; 14/16] END max_depth=30, n_estimators=500;, score=0.731 total time= 3.2min
# [CV 2/2; 14/16] START max_depth=30, n_estimators=500............................
# [CV 2/2; 14/16] END max_depth=30, n_estimators=500;, score=0.732 total time= 3.2min
# [CV 1/2; 15/16] START max_depth=32, n_estimators=360............................
# [CV 1/2; 15/16] END max_depth=32, n_estimators=360;, score=0.727 total time= 2.3min
# [CV 2/2; 15/16] START max_depth=32, n_estimators=360............................
# [CV 2/2; 15/16] END max_depth=32, n_estimators=360;, score=0.728 total time= 2.3min
# [CV 1/2; 16/16] START max_depth=32, n_estimators=500............................
# [CV 1/2; 16/16] END max_depth=32, n_estimators=500;, score=0.727 total time= 3.2min
# [CV 2/2; 16/16] START max_depth=32, n_estimators=500............................
# [CV 2/2; 16/16] END max_depth=32, n_estimators=500;, score=0.728 total time= 3.2min
# [Voting] .................... (2 of 3) Processing extra, total=54.0min
# [Voting] ................. (3 of 3) Processing gradient, total=10.9min
# CPU times: user 1h 2min 25s, sys: 3min 43s, total: 1h 6min 8s
# Wall time: 1h 5min 58s

# %%
preds_1=voting_clf_1.predict(fx_tr)
preds_2=voting_clf_2.predict(fx_tr)
preds_3=voting_clf_3.predict(fx_tr)
preds_4=voting_clf_4.predict(fx_tr)
preds_5=voting_clf_5.predict(fx_tr)
preds_6=voting_clf_6.predict(fx_tr)

#f1 score is the metric used in the competition
score_1=f1_score(fy_tr,preds_1,average='micro')
score_2=f1_score(fy_tr,preds_2,average='micro')
score_3=f1_score(fy_tr,preds_3,average='micro')
score_4=f1_score(fy_tr,preds_4,average='micro')
score_5=f1_score(fy_tr,preds_5,average='micro')
score_6=f1_score(fy_tr,preds_6,average='micro')

print(score_1)
print(score_2)
print(score_3)
print(score_4)
print(score_5)
print(score_6)
# Out:
# 0.8443712802329999
# 0.8339607292374166
# 0.8368348548163667
# 0.8309407868734195
# 0.8625945410800419
# 0.848419614659959

# %% [markdown]
# # Envio

# %%
preds_1=voting_clf_1.predict(fx_te)
preds_2=voting_clf_2.predict(fx_te)
preds_3=voting_clf_3.predict(fx_te)
preds_4=voting_clf_4.predict(fx_te)
preds_5=voting_clf_5.predict(fx_te)
preds_6=voting_clf_6.predict(fx_te)

# %%
sub_csv = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Richter's Predictor: Modeling Earthquake Damage/data/submission_format.csv")

sub_csv["damage_grade"] = preds_1
sub_csv.to_csv("/content/drive/My Drive/Colab Notebooks/Richter's Predictor: Modeling Earthquake Damage/output/submit/ensemble_feature_engineering_teste_1.csv", index=False)

sub_csv["damage_grade"] = preds_2
sub_csv.to_csv("/content/drive/My Drive/Colab Notebooks/Richter's Predictor: Modeling Earthquake Damage/output/submit/ensemble_feature_engineering_teste_2.csv", index=False)

sub_csv["damage_grade"] = preds_3
sub_csv.to_csv("/content/drive/My Drive/Colab Notebooks/Richter's Predictor: Modeling Earthquake Damage/output/submit/ensemble_feature_engineering_teste_3.csv", index=False)

sub_csv["damage_grade"] = preds_4
sub_csv.to_csv("/content/drive/My Drive/Colab Notebooks/Richter's Predictor: Modeling Earthquake Damage/output/submit/ensemble_feature_engineering_teste_4.csv", index=False)

sub_csv["damage_grade"] = preds_5
sub_csv.to_csv("/content/drive/My Drive/Colab Notebooks/Richter's Predictor: Modeling Earthquake Damage/output/submit/ensemble_feature_engineering_teste_5.csv", index=False)

sub_csv["damage_grade"] = preds_6
sub_csv.to_csv("/content/drive/My Drive/Colab Notebooks/Richter's Predictor: Modeling Earthquake Damage/output/submit/ensemble_feature_engineering_teste_6.csv", index=False)
