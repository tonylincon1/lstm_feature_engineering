# %% [markdown]
# # Predicting Earthquake damage to buildings

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd

from tqdm.notebook import tqdm

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, LSTM, Embedding

from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
from imblearn.over_sampling import SMOTE

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Loading

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# path has been removed to maintain privacy
X = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Richter's Predictor: Modeling Earthquake Damage/data/train_values.csv", index_col='building_id')

# %%
X.head()
# Out:
#              geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# building_id
# 802906                    6             487           12198
# 28830                     8             900            2812
# 94947                    21             363            8973
# 590882                   22             418           10694
# 201944                   11             131            1488
#
#              count_floors_pre_eq  age  area_percentage  height_percentage  \
# building_id
# 802906                         2   30                6                  5
# 28830                          2   10                8                  7
# 94947                          2   10                5                  5
# 590882                         2   10                6                  5
# 201944                         3   30                8                  9
#
#             land_surface_condition foundation_type roof_type  ...  \
# building_id                                                   ...
# 802906                           t               r         n  ...
# 28830                            o               r         n  ...
# 94947                            t               r         n  ...
# 590882                           t               r         n  ...
# 201944                           t               r         n  ...
#
#             has_secondary_use_agriculture has_secondary_use_hotel  \
# building_id
# 802906                                  0                       0
# 28830                                   0                       0
# 94947                                   0                       0
# 590882                                  0                       0
# 201944                                  0                       0
#
#             has_secondary_use_rental has_secondary_use_institution  \
# building_id
# 802906                             0                             0
# 28830                              0                             0
# 94947                              0                             0
# 590882                             0                             0
# 201944                             0                             0
#
#              has_secondary_use_school  has_secondary_use_industry  \
# building_id
# 802906                              0                           0
# 28830                               0                           0
# 94947                               0                           0
# 590882                              0                           0
# 201944                              0                           0
#
#              has_secondary_use_health_post  has_secondary_use_gov_office  \
# building_id
# 802906                                   0                             0
# 28830                                    0                             0
# 94947                                    0                             0
# 590882                                   0                             0
# 201944                                   0                             0
#
#              has_secondary_use_use_police  has_secondary_use_other
# building_id
# 802906                                  0                        0
# 28830                                   0                        0
# 94947                                   0                        0
# 590882                                  0                        0
# 201944                                  0                        0
#
# [5 rows x 38 columns]

# %%
# path has been removed to maintain privacy
Y= pd.read_csv("/content/drive/My Drive/Colab Notebooks/Richter's Predictor: Modeling Earthquake Damage/data/train_labels.csv", index_col='building_id')

# %%
Y.head()
# Out:
#              damage_grade
# building_id
# 802906                  3
# 28830                   2
# 94947                   3
# 590882                  2
# 201944                  3

# %%
# path has been removed to maintain privacy
test = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Richter's Predictor: Modeling Earthquake Damage/data/test_values.csv", index_col='building_id')

# %%
X.describe()
# Out:
#        geo_level_1_id  geo_level_2_id  geo_level_3_id  count_floors_pre_eq  \
# count   260601.000000   260601.000000   260601.000000        260601.000000
# mean        13.900353      701.074685     6257.876148             2.129723
# std          8.033617      412.710734     3646.369645             0.727665
# min          0.000000        0.000000        0.000000             1.000000
# 25%          7.000000      350.000000     3073.000000             2.000000
# 50%         12.000000      702.000000     6270.000000             2.000000
# 75%         21.000000     1050.000000     9412.000000             2.000000
# max         30.000000     1427.000000    12567.000000             9.000000
#
#                  age  area_percentage  height_percentage  \
# count  260601.000000    260601.000000      260601.000000
# mean       26.535029         8.018051           5.434365
# std        73.565937         4.392231           1.918418
# min         0.000000         1.000000           2.000000
# 25%        10.000000         5.000000           4.000000
# 50%        15.000000         7.000000           5.000000
# 75%        30.000000         9.000000           6.000000
# max       995.000000       100.000000          32.000000
#
#        has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  \
# count                 260601.000000                        260601.000000
# mean                       0.088645                             0.761935
# std                        0.284231                             0.425900
# min                        0.000000                             0.000000
# 25%                        0.000000                             1.000000
# 50%                        0.000000                             1.000000
# 75%                        0.000000                             1.000000
# max                        1.000000                             1.000000
#
#        has_superstructure_stone_flag  ...  has_secondary_use_agriculture  \
# count                  260601.000000  ...                  260601.000000
# mean                        0.034332  ...                       0.064378
# std                         0.182081  ...                       0.245426
# min                         0.000000  ...                       0.000000
# 25%                         0.000000  ...                       0.000000
# 50%                         0.000000  ...                       0.000000
# 75%                         0.000000  ...                       0.000000
# max                         1.000000  ...                       1.000000
#
#        has_secondary_use_hotel  has_secondary_use_rental  \
# count            260601.000000             260601.000000
# mean                  0.033626                  0.008101
# std                   0.180265                  0.089638
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   0.000000                  0.000000
# 75%                   0.000000                  0.000000
# max                   1.000000                  1.000000
#
#        has_secondary_use_institution  has_secondary_use_school  \
# count                  260601.000000             260601.000000
# mean                        0.000940                  0.000361
# std                         0.030647                  0.018989
# min                         0.000000                  0.000000
# 25%                         0.000000                  0.000000
# 50%                         0.000000                  0.000000
# 75%                         0.000000                  0.000000
# max                         1.000000                  1.000000
#
#        has_secondary_use_industry  has_secondary_use_health_post  \
# count               260601.000000                  260601.000000
# mean                     0.001071                       0.000188
# std                      0.032703                       0.013711
# min                      0.000000                       0.000000
# 25%                      0.000000                       0.000000
# 50%                      0.000000                       0.000000
# 75%                      0.000000                       0.000000
# max                      1.000000                       1.000000
#
#        has_secondary_use_gov_office  has_secondary_use_use_police  \
# count                 260601.000000                 260601.000000
# mean                       0.000146                      0.000088
# std                        0.012075                      0.009394
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.000000                      0.000000
# 75%                        0.000000                      0.000000
# max                        1.000000                      1.000000
#
#        has_secondary_use_other
# count            260601.000000
# mean                  0.005119
# std                   0.071364
# min                   0.000000
# 25%                   0.000000
# 50%                   0.000000
# 75%                   0.000000
# max                   1.000000
#
# [8 rows x 30 columns]

# %% [markdown]
# # EDA

# %%
sns.countplot(Y['damage_grade'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Feature Engineering : Conditional Probabilities of geo_levels

# %% [markdown]
# #### ID-1

# %%
fea = pd.merge(X, Y, on='building_id')

# %%
#this block of code calculates the probabilities
damage1 = {}
damage2 = {}
damage3 = {}

for i,j in (X['geo_level_1_id'].value_counts()).iteritems():
    
    n1 = len(fea[fea['damage_grade']==1][fea['geo_level_1_id']==i])
    n2 = len(fea[fea['damage_grade']==2][fea['geo_level_1_id']==i])
    n3 = len(fea[fea['damage_grade']==3][fea['geo_level_1_id']==i])

    damage1[i] = n1/j
    damage2[i] = n2/j
    damage3[i] = n3/j
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # Remove the CWD from sys.path while we load stuff.

# %%
# this block of code appends a new column/feature of probabilities
list1 = []
list2 = []
list3 = []

for i in X['geo_level_1_id']:
    list1.append(damage1.get(i))
    list2.append(damage2.get(i))
    list3.append(damage3.get(i))

X['prob1_geo1'] = list1
X['prob2_geo1'] = list2
X['prob3_geo1'] = list3

# %%
list1 = []
list2 = []
list3 = []

for i in test['geo_level_1_id']:
    list1.append(damage1.get(i))
    list2.append(damage2.get(i))
    list3.append(damage3.get(i))

test['prob1_geo1'] = list1
test['prob2_geo1'] = list2
test['prob3_geo1'] = list3

# %% [markdown]
# #### ID-2

# %%
damage1 = {}
damage2 = {}
damage3 = {}

for i,j in ((X['geo_level_2_id'].value_counts()).iteritems()):
    
    n1 = len(fea[fea['damage_grade']==1][fea['geo_level_2_id']==i])
    n2 = len(fea[fea['damage_grade']==2][fea['geo_level_2_id']==i])
    n3 = len(fea[fea['damage_grade']==3][fea['geo_level_2_id']==i])

    damage1[i] = n1/j
    damage2[i] = n2/j
    damage3[i] = n3/j
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':

# %%
list1 = []
list2 = []
list3 = []

for i in X['geo_level_2_id']:
    list1.append(damage1.get(i))
    list2.append(damage2.get(i))
    list3.append(damage3.get(i))

X['prob1_geo2'] = list1
X['prob2_geo2'] = list2
X['prob3_geo2'] = list3

# %%
list1 = []
list2 = []
list3 = []

for i in test['geo_level_2_id']:
    list1.append(damage1.get(i))
    list2.append(damage2.get(i))
    list3.append(damage3.get(i))

test['prob1_geo2'] = list1
test['prob2_geo2'] = list2
test['prob3_geo2'] = list3

# %% [markdown]
# #### ID-3

# %%
damage1 = {}
damage2 = {}
damage3 = {}

for i,j in ((X['geo_level_3_id'].value_counts()).iteritems()):
    
    n1 = len(fea[fea['damage_grade']==1][fea['geo_level_3_id']==i])
    n2 = len(fea[fea['damage_grade']==2][fea['geo_level_3_id']==i])
    n3 = len(fea[fea['damage_grade']==3][fea['geo_level_3_id']==i])

    damage1[i] = n1/j
    damage2[i] = n2/j
    damage3[i] = n3/j
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':

# %%
list1 = []
list2 = []
list3 = []

for i in X['geo_level_3_id']:
    list1.append(damage1.get(i))
    list2.append(damage2.get(i))
    list3.append(damage3.get(i))

X['prob1_geo3'] = list1
X['prob2_geo3'] = list2
X['prob3_geo3'] = list3

# %%
list1 = []
list2 = []
list3 = []

for i in test['geo_level_3_id']:
    list1.append(damage1.get(i))
    list2.append(damage2.get(i))
    list3.append(damage3.get(i))

test['prob1_geo3'] = list1
test['prob2_geo3'] = list2
test['prob3_geo3'] = list3

# %% [markdown]
# # Feature Engineering: Finding relation between geo_levels using seq_to_seq method (LSTM)

# %% [markdown]
# <font size=2> **Below is just an example to show how the geo_levels might be related in some way to each other.**
# **For geo_level_1 = 6 and geo_level_2=487 we see there are a lot of same geo_levels-3 indicating that there is some relation between these levels.**</font>

# %%
pd.DataFrame(X['geo_level_3_id'][X['geo_level_2_id']==487][X['geo_level_1_id']==6]).head(50)
# Out:
#              geo_level_3_id
# building_id
# 802906                12198
# 959468                12198
# 410679                 7439
# 423950                 7439
# 215003                12198
# 594969                  835
# 695349                 2908
# 869506                 7439
# 141511                  382
# 302373                12198
# 278030                 7439
# 468643                  139
# 301912                 7439
# 361127                  835
# 434762                 6936
# 820534                12198
# 403828                 1755
# 1003118                 139
# 11938                   382
# 323241                 7439
# 644442                  139
# 569291                12198
# 260227                  139
# 283562                  382
# 483948                12198
# 900047                  139
# 241763                 1755
# 138804                  139
# 412505                 1755
# 226288                  139
# 581654                  835
# 505958                 2908
# 332220                 6845
# 477823                12198
# 15925                  1755
# 876711                  382
# 298595                 1755
# 473330                  139
# 496583                  139
# 925649                  139
# 163967                12198
# 122224                12198
# 1052883                6845
# 313465                 6936
# 408889                 6845
# 835066                 7439
# 471550                 1755
# 516173                12198
# 860736                 1755
# 232308                  139

# %% [markdown]
# ### Converting the geo_levels 1 and 2 into one hot encoder with shared vocabulary

# %%
l1 = pd.concat([X['geo_level_1_id'], test['geo_level_1_id']])
l2 = pd.concat([X['geo_level_2_id'], test['geo_level_2_id']])
l3 = pd.concat([X['geo_level_3_id'], test['geo_level_3_id']])

# %%
#get shared vocab of l1 and l2
inp = pd.concat([l1,l2]).to_numpy().reshape(-1,1)

# %%
l1 = pd.concat([X['geo_level_1_id'], test['geo_level_1_id']]).to_numpy().reshape(-1,1)

# %%
l2 = pd.concat([X['geo_level_2_id'], test['geo_level_2_id']]).to_numpy().reshape(-1,1)

# %%
onehot = OneHotEncoder(sparse=False)

# %%
onehot.fit(inp)
# Out:
# OneHotEncoder(sparse=False)

# %%
inp.shape
# Out:
# (694938, 1)

# %%
onehot.categories_
# Out:
# [array([   0,    1,    2, ..., 1425, 1426, 1427])]

# %%
l1_hot = onehot.transform(l1)

# %%
l1_hot.shape
# Out:
# (347469, 1419)

# %%
l2_hot = onehot.transform(l2)

# %%
l2_hot.shape
# Out:
# (347469, 1419)

# %%
fin_inp = np.stack((l1_hot,l2_hot), axis=1)
fin_inp.shape
# Out:
# (347469, 2, 1419)

# %% [markdown]
# ### Converting geo_level_3 into onehot

# %%
l3_hot = np.array(pd.get_dummies(l3))

# %%
l3_hot.shape
# Out:
# (347469, 11861)

# %% [markdown]
# ### Creating a LSTM model to get relation features.

# %%
inpx = Input( shape=fin_inp.shape[1:] )  

lstm = LSTM(20, )(inpx)

lvl3 = Dense(l3_hot.shape[1], activation='sigmoid')(lstm)

modelf = Model(inputs= inpx, outputs=lvl3)

modelf.compile(loss='binary_crossentropy', optimizer='adam')

modelf.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2, 1419)]         0
#
#  lstm (LSTM)                 (None, 20)                115200
#
#  dense (Dense)               (None, 11861)             249081
#
# =================================================================
# Total params: 364,281
# Trainable params: 364,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelf.fit(fin_inp, l3_hot, epochs=10, batch_size=64)
# Out:
# Epoch 1/10
# 5430/5430 [==============================] - 28s 4ms/step - loss: 0.0184
# Epoch 2/10
# 5430/5430 [==============================] - 21s 4ms/step - loss: 8.3740e-04
# Epoch 3/10
# 5430/5430 [==============================] - 21s 4ms/step - loss: 8.3150e-04
# Epoch 4/10
# 5430/5430 [==============================] - 20s 4ms/step - loss: 8.3097e-04
# Epoch 5/10
# 5430/5430 [==============================] - 21s 4ms/step - loss: 8.3007e-04
# Epoch 6/10
# 5430/5430 [==============================] - 21s 4ms/step - loss: 8.0062e-04
# Epoch 7/10
# 5430/5430 [==============================] - 21s 4ms/step - loss: 7.4587e-04
# Epoch 8/10
# 5430/5430 [==============================] - 20s 4ms/step - loss: 7.0979e-04
# Epoch 9/10
# 5430/5430 [==============================] - 21s 4ms/step - loss: 6.7716e-04
# Epoch 10/10
# 5430/5430 [==============================] - 20s 4ms/step - loss: 6.5655e-04

# %% [markdown]
# ### Getting the relation vector from the output of intermediate layer

# %%
inter = Model(inputs=modelf.input, outputs=modelf.layers[1].output)

# %% [markdown]
# <font size=3>**Train**</font>

# %%
l1 = X['geo_level_1_id'].to_numpy().reshape(-1,1)

l2 = X['geo_level_2_id'].to_numpy().reshape(-1,1)

# %%
l1_hot = onehot.transform(l1)
l2_hot = onehot.transform(l2)

# %%
fin_inp = np.stack((l1_hot,l2_hot), axis=1)
fin_inp.shape
# Out:
# (260601, 2, 1419)

# %%
geo_fea_train = inter.predict(fin_inp)

# %% [markdown]
# <font size=3>**Test**</font>

# %%
l1 = test['geo_level_1_id'].to_numpy().reshape(-1,1)

l2 = test['geo_level_2_id'].to_numpy().reshape(-1,1)

# %%
l1_hot = onehot.transform(l1)
l2_hot = onehot.transform(l2)

# %%
fin_inp = np.stack((l1_hot,l2_hot), axis=1)
fin_inp.shape
# Out:
# (86868, 2, 1419)

# %%
geo_fea_test = inter.predict(fin_inp)

# %% [markdown]
# # Final  Data

# %%
print("train {}, test {}  ".format(geo_fea_train.shape, geo_fea_test.shape))
# Out:
# train (260601, 20), test (86868, 20)

# %% [markdown]
# ### Preprocessing the data with pd.get_dummies and adding the relation features

# %%
fx_tr = np.hstack((np.array(pd.get_dummies(X.copy().drop(['geo_level_1_id', 'geo_level_2_id', 'geo_level_3_id'], axis=1))),
                   geo_fea_train))

# %%
fx_tr
# Out:
# array([[ 2.        , 30.        ,  6.        , ...,  0.9626537 ,
#         -0.96311986, -0.9628492 ],
#        [ 2.        , 10.        ,  8.        , ...,  0.96253055,
#          0.96242064, -0.96274453],
#        [ 2.        , 10.        ,  5.        , ...,  0.96315593,
#         -0.96333766, -0.96306914],
#        ...,
#        [ 3.        , 55.        ,  6.        , ...,  0.96321177,
#         -0.9632625 , -0.96316946],
#        [ 2.        , 10.        , 14.        , ...,  0.96296054,
#         -0.96361381, -0.96346641],
#        [ 3.        , 10.        ,  7.        , ...,  0.96315837,
#         -0.96333665, -0.96307564]])

# %%
fx_tr.shape
# Out:
# (260601, 94)

# %%
test.fillna(value=0, inplace=True)

# %%
fx_te = np.hstack((np.array(pd.get_dummies(test.copy().drop(['geo_level_1_id', 'geo_level_2_id', 'geo_level_3_id'], axis=1))), geo_fea_test))

fx_te.shape
# Out:
# (86868, 94)

# %%
fy_tr = Y.to_numpy().ravel()
fy_tr.shape
# Out:
# (260601,)

# %% [markdown]
# # Applying machine learning

# %%
rf = RandomForestClassifier(n_estimators = 500,random_state = 1, max_depth=None,n_jobs=-1)
rf.fit(fx_tr,fy_tr)
predrf=rf.predict(fx_tr)

#f1 score is the metric used in the competition
accuracy1=f1_score(fy_tr,predrf,average='micro')
print("Score on test set")
print("\n ========================================================")
print(accuracy1)
print('\n Benchmark model was: 0.984')
# Out:
# Score on test set
#
#  ========================================================
# 0.9842057398091335
#
#  Benchmark model was: 0.984

# %%
import lightgbm as lgb

modellgb = lgb.LGBMClassifier(random_seed=42,objective="multiclass",
        num_class=3,
        metric="multi_error",
        boosting= 'gbdt',
        max_depth= -1,
        num_leaves= 30,
        learning_rate= 0.1,
        feature_fraction= 0.5,
        min_sum_hessian_in_leaf= 0.1,
        max_bin=8192,
        verbosity= 1,
        num_threads=6)
modellgb.fit(fx_tr, fy_tr)
predslgb=modellgb.predict(fx_tr)

#f1 score is the metric used in the competition
accuracy1=f1_score(fy_tr,predslgb,average='micro')
print("Score on test set")
print("\n ========================================================")
print(accuracy1)
print('\n Benchmark model was: 0.7898')
# Out:
# Score on test set
#
#  ========================================================
# 0.7656340535915058
#
#  Benchmark model was: 0.7898

# %%
import lightgbm as lgb

modellgb = lgb.LGBMClassifier(verbose=10)

gridParams = {
    'learning_rate': [0.005, 0.01],
    'n_estimators': [50,100,300],
    'num_leaves': [6,8,12], # large num_leaves helps improve accuracy but might lead to over-fitting
    'boosting_type' : ['gbdt', 'dart'], # for better accuracy -> try dart
    'objective' : ['multiclass'],
    'max_bin':[255, 510], # large max_bin helps improve accuracy but might slow down training progress
    'random_state' : [42],
    'colsample_bytree' : [0.64, 0.66],
    'subsample' : [0.7,0.75],
    'reg_alpha' : [1,1.2],
    'reg_lambda' : [1,1.4],
    }

modellgb = GridSearchCV(modellgb, gridParams, cv=2, scoring='f1_micro', verbose=10)
modellgb.fit(fx_tr, fy_tr,verbose=10)
predslgb=modellgb.predict(fx_tr)

#f1 score is the metric used in the competition
accuracy1=f1_score(fy_tr,predslgb,average='micro')
print("Score on test set")
print("\n ========================================================")
print(accuracy1)
print('\n Benchmark model was: 0.7898')
# Out:
# Fitting 2 folds for each of 1152 candidates, totalling 2304 fits
# [CV 1/2; 1/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 1/2; 1/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.569 total time=   3.6s
# [CV 2/2; 1/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 2/2; 1/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.569 total time=   1.5s
# [CV 1/2; 2/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 1/2; 2/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.569 total time=   1.5s
# [CV 2/2; 2/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 2/2; 2/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.569 total time=   1.5s
# [CV 1/2; 3/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 3/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.569 total time=   1.5s
# [CV 2/2; 3/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 3/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.569 total time=   1.5s
# [CV 1/2; 4/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 4/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.569 total time=   1.5s
# [CV 2/2; 4/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 4/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.569 total time=   1.5s
# [CV 1/2; 5/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7
# [CV 1/2; 5/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7;, score=0.569 total time=   1.5s
# [CV 2/2; 5/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7
# [CV 2/2; 5/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7;, score=0.569 total time=   1.5s
# [CV 1/2; 6/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75
# [CV 1/2; 6/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75;, score=0.569 total time=   1.5s
# [CV 2/2; 6/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75
# [CV 2/2; 6/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75;, score=0.569 total time=   1.5s
# [CV 1/2; 7/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 7/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7;, score=0.569 total time=   1.5s
# [CV 2/2; 7/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 7/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7;, score=0.569 total time=   1.5s
# [CV 1/2; 8/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 8/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.569 total time=   1.5s
# [CV 2/2; 8/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 8/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.569 total time=   1.5s
# [CV 1/2; 9/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 1/2; 9/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.569 total time=   1.6s
# [CV 2/2; 9/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 2/2; 9/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.569 total time=   1.6s
# [CV 1/2; 10/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 1/2; 10/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.569 total time=   1.6s
# [CV 2/2; 10/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 2/2; 10/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.569 total time=   1.6s
# [CV 1/2; 11/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 11/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.569 total time=   1.6s
# [CV 2/2; 11/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 11/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.569 total time=   1.6s
# [CV 1/2; 12/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 12/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.569 total time=   1.7s
# [CV 2/2; 12/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 12/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.569 total time=   1.6s
# [CV 1/2; 13/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7
# [CV 1/2; 13/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7;, score=0.569 total time=   1.6s
# [CV 2/2; 13/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7
# [CV 2/2; 13/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7;, score=0.569 total time=   1.6s
# [CV 1/2; 14/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75
# [CV 1/2; 14/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75;, score=0.569 total time=   1.6s
# [CV 2/2; 14/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75
# [CV 2/2; 14/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75;, score=0.569 total time=   1.6s
# [CV 1/2; 15/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 15/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7;, score=0.569 total time=   1.6s
# [CV 2/2; 15/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 15/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7;, score=0.569 total time=   1.6s
# [CV 1/2; 16/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 16/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.569 total time=   1.6s
# [CV 2/2; 16/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 16/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.569 total time=   1.6s
# [CV 1/2; 17/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 1/2; 17/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.569 total time=   1.8s
# [CV 2/2; 17/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 2/2; 17/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.569 total time=   1.8s
# [CV 1/2; 18/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 1/2; 18/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.569 total time=   1.8s
# [CV 2/2; 18/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 2/2; 18/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.569 total time=   1.8s
# [CV 1/2; 19/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 19/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.569 total time=   1.8s
# [CV 2/2; 19/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 19/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.569 total time=   1.8s
# [CV 1/2; 20/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 20/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.569 total time=   1.8s
# [CV 2/2; 20/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 20/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.569 total time=   1.8s
# [CV 1/2; 21/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7
# [CV 1/2; 21/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7;, score=0.569 total time=   1.8s
# [CV 2/2; 21/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7
# [CV 2/2; 21/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7;, score=0.569 total time=   1.8s
# [CV 1/2; 22/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75
# [CV 1/2; 22/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75;, score=0.569 total time=   1.7s
# [CV 2/2; 22/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75
# [CV 2/2; 22/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75;, score=0.569 total time=   1.7s
# [CV 1/2; 23/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 23/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7;, score=0.569 total time=   1.7s
# [CV 2/2; 23/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 23/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7;, score=0.569 total time=   1.7s
# [CV 1/2; 24/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 24/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.569 total time=   1.8s
# [CV 2/2; 24/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 24/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=50, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.569 total time=   1.7s
# [CV 1/2; 25/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 1/2; 25/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.695 total time=   2.4s
# [CV 2/2; 25/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 2/2; 25/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.693 total time=   2.4s
# [CV 1/2; 26/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 1/2; 26/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.695 total time=   2.4s
# [CV 2/2; 26/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 2/2; 26/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.693 total time=   2.5s
# [CV 1/2; 27/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 27/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.695 total time=   2.4s
# [CV 2/2; 27/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 27/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.693 total time=   2.4s
# [CV 1/2; 28/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 28/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.695 total time=   2.4s
# [CV 2/2; 28/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 28/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.693 total time=   2.4s
# [CV 1/2; 29/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7
# [CV 1/2; 29/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7;, score=0.695 total time=   2.4s
# [CV 2/2; 29/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7
# [CV 2/2; 29/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7;, score=0.693 total time=   2.4s
# [CV 1/2; 30/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75
# [CV 1/2; 30/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75;, score=0.695 total time=   2.4s
# [CV 2/2; 30/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75
# [CV 2/2; 30/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75;, score=0.693 total time=   2.4s
# [CV 1/2; 31/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 31/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7;, score=0.695 total time=   2.4s
# [CV 2/2; 31/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 31/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7;, score=0.693 total time=   2.4s
# [CV 1/2; 32/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 32/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.695 total time=   2.4s
# [CV 2/2; 32/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 32/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.693 total time=   2.3s
# [CV 1/2; 33/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 1/2; 33/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.695 total time=   2.7s
# [CV 2/2; 33/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 2/2; 33/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.692 total time=   2.6s
# [CV 1/2; 34/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 1/2; 34/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.695 total time=   2.6s
# [CV 2/2; 34/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 2/2; 34/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.692 total time=   2.6s
# [CV 1/2; 35/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 35/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.695 total time=   2.6s
# [CV 2/2; 35/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 35/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.692 total time=   2.6s
# [CV 1/2; 36/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 36/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.695 total time=   2.6s
# [CV 2/2; 36/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 36/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.692 total time=   2.6s
# [CV 1/2; 37/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7
# [CV 1/2; 37/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7;, score=0.695 total time=   2.7s
# [CV 2/2; 37/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7
# [CV 2/2; 37/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7;, score=0.692 total time=   2.7s
# [CV 1/2; 38/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75
# [CV 1/2; 38/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75;, score=0.695 total time=   2.6s
# [CV 2/2; 38/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75
# [CV 2/2; 38/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75;, score=0.692 total time=   2.7s
# [CV 1/2; 39/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 39/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7;, score=0.695 total time=   2.7s
# [CV 2/2; 39/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 39/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7;, score=0.692 total time=   2.6s
# [CV 1/2; 40/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 40/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.695 total time=   2.7s
# [CV 2/2; 40/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 40/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.692 total time=   2.7s
# [CV 1/2; 41/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 1/2; 41/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.695 total time=   2.9s
# [CV 2/2; 41/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 2/2; 41/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.692 total time=   2.9s
# [CV 1/2; 42/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 1/2; 42/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.695 total time=   2.9s
# [CV 2/2; 42/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 2/2; 42/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.692 total time=   3.0s
# [CV 1/2; 43/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 43/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.695 total time=   3.0s
# [CV 2/2; 43/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 43/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.692 total time=   3.0s
# [CV 1/2; 44/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 44/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.695 total time=   3.0s
# [CV 2/2; 44/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 44/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.692 total time=   2.9s
# [CV 1/2; 45/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7
# [CV 1/2; 45/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7;, score=0.695 total time=   3.0s
# [CV 2/2; 45/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7
# [CV 2/2; 45/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7;, score=0.692 total time=   2.9s
# [CV 1/2; 46/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75
# [CV 1/2; 46/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75;, score=0.695 total time=   2.9s
# [CV 2/2; 46/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75
# [CV 2/2; 46/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75;, score=0.692 total time=   2.9s
# [CV 1/2; 47/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 47/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7;, score=0.696 total time=   2.9s
# [CV 2/2; 47/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 47/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7;, score=0.692 total time=   2.9s
# [CV 1/2; 48/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 48/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.696 total time=   2.9s
# [CV 2/2; 48/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 48/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=100, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.692 total time=   2.9s
# [CV 1/2; 49/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 1/2; 49/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.738 total time=   6.2s
# [CV 2/2; 49/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 2/2; 49/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.738 total time=   6.3s
# [CV 1/2; 50/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 1/2; 50/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.738 total time=   6.2s
# [CV 2/2; 50/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 2/2; 50/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.738 total time=   6.2s
# [CV 1/2; 51/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 51/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.738 total time=   6.2s
# [CV 2/2; 51/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 51/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.738 total time=   6.2s
# [CV 1/2; 52/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 52/1152] END boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.738 total time=   6.3s
# [CV 2/2; 52/1152] START boosting_type=gbdt, colsample_bytree=0.64, learning_rate=0.005, max_bin=255, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# ...
# [CV 1/2; 1136/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 1136/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.742 total time=  16.8s
# [CV 2/2; 1136/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 1136/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=6, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.741 total time=  16.7s
# [CV 1/2; 1137/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 1/2; 1137/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.743 total time=  19.1s
# [CV 2/2; 1137/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 2/2; 1137/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.743 total time=  18.7s
# [CV 1/2; 1138/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 1/2; 1138/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.743 total time=  19.3s
# [CV 2/2; 1138/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 2/2; 1138/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.743 total time=  18.9s
# [CV 1/2; 1139/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 1139/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.743 total time=  19.3s
# [CV 2/2; 1139/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 1139/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.743 total time=  18.7s
# [CV 1/2; 1140/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 1140/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.743 total time=  19.2s
# [CV 2/2; 1140/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 1140/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.743 total time=  18.7s
# [CV 1/2; 1141/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7
# [CV 1/2; 1141/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7;, score=0.742 total time=  19.0s
# [CV 2/2; 1141/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7
# [CV 2/2; 1141/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7;, score=0.743 total time=  19.1s
# [CV 1/2; 1142/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75
# [CV 1/2; 1142/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75;, score=0.742 total time=  19.0s
# [CV 2/2; 1142/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75
# [CV 2/2; 1142/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75;, score=0.743 total time=  19.0s
# [CV 1/2; 1143/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 1143/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7;, score=0.743 total time=  20.0s
# [CV 2/2; 1143/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 1143/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7;, score=0.743 total time=  19.8s
# [CV 1/2; 1144/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 1144/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.743 total time=  19.6s
# [CV 2/2; 1144/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 1144/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=8, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.743 total time=  18.9s
# [CV 1/2; 1145/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 1/2; 1145/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.746 total time=  22.4s
# [CV 2/2; 1145/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7
# [CV 2/2; 1145/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7;, score=0.746 total time=  22.4s
# [CV 1/2; 1146/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 1/2; 1146/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.746 total time=  22.5s
# [CV 2/2; 1146/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75
# [CV 2/2; 1146/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.75;, score=0.746 total time=  22.4s
# [CV 1/2; 1147/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 1147/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.746 total time=  22.4s
# [CV 2/2; 1147/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 1147/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.7;, score=0.746 total time=  22.4s
# [CV 1/2; 1148/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 1148/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.746 total time=  22.6s
# [CV 2/2; 1148/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 1148/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1, reg_lambda=1.4, subsample=0.75;, score=0.746 total time=  22.3s
# [CV 1/2; 1149/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7
# [CV 1/2; 1149/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7;, score=0.746 total time=  22.7s
# [CV 2/2; 1149/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7
# [CV 2/2; 1149/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.7;, score=0.746 total time=  22.3s
# [CV 1/2; 1150/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75
# [CV 1/2; 1150/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75;, score=0.746 total time=  22.8s
# [CV 2/2; 1150/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75
# [CV 2/2; 1150/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1, subsample=0.75;, score=0.746 total time=  22.7s
# [CV 1/2; 1151/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV 1/2; 1151/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7;, score=0.746 total time=  22.8s
# [CV 2/2; 1151/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7
# [CV 2/2; 1151/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.7;, score=0.746 total time=  22.4s
# [CV 1/2; 1152/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 1/2; 1152/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.746 total time=  22.5s
# [CV 2/2; 1152/1152] START boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75
# [CV 2/2; 1152/1152] END boosting_type=dart, colsample_bytree=0.66, learning_rate=0.01, max_bin=510, n_estimators=300, num_leaves=12, objective=multiclass, random_state=42, reg_alpha=1.2, reg_lambda=1.4, subsample=0.75;, score=0.746 total time=  23.0s
# Score on test set
#
#  ========================================================
# 0.7543486018856412
#
#  Benchmark model was: 0.7898

# %%
modellgb.cv_results_
# Out:
# {'mean_fit_time': array([ 2.3995434 ,  1.35261714,  1.35541844, ..., 21.88125646,
#         21.74431932, 21.89607191]),
#  'mean_score_time': array([0.13559699, 0.13833964, 0.1371206 , ..., 0.86025238, 0.87549591,
#         0.87715983]),
#  'mean_test_score': array([0.56891186, 0.56891186, 0.56891186, ..., 0.74584518, 0.74592193,
#         0.74592193]),
#  'param_boosting_type': masked_array(data=['gbdt', 'gbdt', 'gbdt', ..., 'dart', 'dart', 'dart'],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_colsample_bytree': masked_array(data=[0.64, 0.64, 0.64, ..., 0.66, 0.66, 0.66],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_learning_rate': masked_array(data=[0.005, 0.005, 0.005, ..., 0.01, 0.01, 0.01],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_bin': masked_array(data=[255, 255, 255, ..., 510, 510, 510],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[50, 50, 50, ..., 300, 300, 300],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_num_leaves': masked_array(data=[6, 6, 6, ..., 12, 12, 12],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_objective': masked_array(data=['multiclass', 'multiclass', 'multiclass', ...,
#                     'multiclass', 'multiclass', 'multiclass'],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_random_state': masked_array(data=[42, 42, 42, ..., 42, 42, 42],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_reg_alpha': masked_array(data=[1, 1, 1, ..., 1.2, 1.2, 1.2],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_reg_lambda': masked_array(data=[1, 1, 1.4, ..., 1, 1.4, 1.4],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_subsample': masked_array(data=[0.7, 0.75, 0.7, ..., 0.75, 0.7, 0.75],
#               mask=[False, False, False, ..., False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 255,
#    'n_estimators': 300,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'gbdt',
#    'colsample_bytree': 0.64,
#    'learning_rate': 0.01,
#    'max_bin': 255,
# ...
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 50,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 100,
#    'num_leaves': 12,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 6,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1,
#    'subsample': 0.75},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.7},
#   {'boosting_type': 'dart',
#    'colsample_bytree': 0.66,
#    'learning_rate': 0.005,
#    'max_bin': 510,
#    'n_estimators': 300,
#    'num_leaves': 8,
#    'objective': 'multiclass',
#    'random_state': 42,
#    'reg_alpha': 1.2,
#    'reg_lambda': 1.4,
#    'subsample': 0.75},
#   ...],
#  'rank_test_score': array([969, 969, 969, ..., 111, 103, 103], dtype=int32),
#  'split0_test_score': array([0.56891352, 0.56891352, 0.56891352, ..., 0.74561208, 0.74567348,
#         0.74567348]),
#  'split1_test_score': array([0.56891021, 0.56891021, 0.56891021, ..., 0.74607828, 0.74617038,
#         0.74617038]),
#  'std_fit_time': array([1.0231303 , 0.00140822, 0.00204587, ..., 0.00103056, 0.19144738,
#         0.24282908]),
#  'std_score_time': array([0.00256968, 0.00062597, 0.00126922, ..., 0.0155158 , 0.00090313,
#         0.00153995]),
#  'std_test_score': array([1.65420754e-06, 1.65420754e-06, 1.65420754e-06, ...,
#         2.33099049e-04, 2.48448478e-04, 2.48448478e-04])}

# %%
modellgb.best_estimator_
# Out:
# LGBMClassifier(colsample_bytree=0.66, learning_rate=0.01, max_bin=510,
#                n_estimators=300, num_leaves=12, objective='multiclass',
#                random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.7,
#                verbose=10)

# %%
#input best params here from randm.best_params_

# !pip install xgboost

import xgboost as xgb

modelxgb_cl = xgb.XGBClassifier(random_state=42,objective='multi:softmax', gamma=0.001369048068388758, eta=0.11,
                  max_depth= 20,
                  min_child_weight=9,
                  num_class= 4,
                  subsample= .85,
                  colsample_bytree= .9, verbose=10)
modelxgb_cl.fit(fx_tr, fy_tr)

predsxgb_cl=modelxgb_cl.predict(fx_tr)

#f1 score is the metric used in the competition
accuracy1=f1_score(fy_tr,predsxgb_cl,average='micro')
print("Score on test set")
print("\n ========================================================")
print(accuracy1)
print('\n Benchmark model was: 0.8712')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (0.90)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.21.6)
# Score on test set
#
#  ========================================================
# 0.870959819801152
#
#  Benchmark model was: 0.8712

# %%
# %%time

from sklearn.ensemble import VotingClassifier

voting_clf = VotingClassifier(estimators=[('rf', rf),
                                          ('lgb',modellgb),
                                          ('xbg', modelxgb_cl)], voting='soft', verbose=10)
voting_clf.fit(fx_tr, fy_tr)
# Out:
# [Voting] ....................... (1 of 3) Processing rf, total= 1.6min
# [Voting] ...................... (2 of 3) Processing lgb, total=   8.0s
# [Voting] ...................... (3 of 3) Processing xbg, total=23.7min
# CPU times: user 24min 38s, sys: 5.9 s, total: 24min 44s
# Wall time: 25min 23s

# %%
predsvoting=voting_clf.predict(fx_tr)

#f1 score is the metric used in the competition
accuracy1=f1_score(fy_tr,predsvoting,average='micro')
print("Score on test set")
print("\n ========================================================")
print(accuracy1)
print('\n Benchmark model was: 0.9354')
# Out:
# Score on test set
#
#  ========================================================
# 0.9023181031538635
#
#  Benchmark model was: 0.9354

# %% [markdown]
# # Envio

# %%
y_pred = voting_clf.predict(fx_te)

# %%
sub_csv = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Richter's Predictor: Modeling Earthquake Damage/data/submission_format.csv")

sub_csv["damage_grade"] = y_pred
sub_csv.to_csv("/content/drive/My Drive/Colab Notebooks/Richter's Predictor: Modeling Earthquake Damage/output/submit/ensemble_feature_engineering_lgb_paramns.csv", index=False)
